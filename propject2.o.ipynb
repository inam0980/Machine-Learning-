# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt


df=pd.read_csv("student1.csv")

df.head()
# Out:
#    Student_ID  Gender  Age   Department  Attendance_%  Study_Hours_per_Week  \
# 0           1    Male   20           CS         59.91                    30
# 1           2  Female   24  Mathematics         50.46                    31
# 2           3    Male   24     Business         81.36                    44
# 3           4    Male   24  Mathematics         65.82                    28
# 4           5    Male   21  Engineering         98.66                    12
#
#    Midterm_Score  Final_Score  Assignments_Avg  Quizzes_Avg  \
# 0          80.01        50.94            91.05        90.12
# 1          80.22        75.83            69.48        74.07
# 2          94.07        81.59            59.90        91.05
# 3          40.96        68.11            79.38        91.23
# 4          91.18        45.86            91.32        65.86
#
#    Participation_Score  Projects_Score  Total_Score Grade  Backlogs  \
# 0                53.15           71.24        49.68     C         0
# 1                91.63           92.86        57.73     F         1
# 2                90.86           78.17        53.01     A         3
# 3                24.97           52.26        98.52     D         0
# 4                71.97           90.09        61.78     D         3
#
#   Internship Scholarship Sports_Activity Extra_Curricular Placement_Status
# 0        Yes          No              No               No           Placed
# 1         No         Yes             Yes              Yes       Not Placed
# 2        Yes         Yes             Yes               No       Not Placed
# 3        Yes         Yes              No              Yes       Not Placed
# 4        Yes         Yes              No               No       Not Placed

# %%
X=df[["Study_Hours_per_Week"]]

y=df["Final_Score"]

# %%
model=LinearRegression()

model.fit(X,y)

predict= model.predict(X)

# %%
mae=mean_absolute_error(y,predict)

mse=mean_squared_error(y,predict)

rmse=np.sqrt(mse)

r=r2_score(y,predict)

print("Mean Absolute Error:- ",round(mae,2))
print("Mean Squared Error:-  ",round(mse,2))
print("rms:-                 ",round(rmse,2))
print("r2:-                  ",round(r,2))

plt.figure(figsize=(10,6))
plt.hist(df["Final_Score"], bins=30, color='skyblue', edgecolor='black')
plt.grid(True)
plt.legend()
plt.xlabel("score")
plt.ylabel("NUmber of Student")
plt.title("Distribution of final score")
plt.show()
# Out:
# Mean Absolute Error:-  14.83
# Mean Squared Error:-   294.78
# rms:-                  17.17
# r2:-                   0.0
# /var/folders/rh/5xfb27r55ql68l4zwc899mw80000gn/T/ipykernel_13573/3755463768.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            5000 non-null   int64
#  1   Gender                5000 non-null   object
#  2   Age                   5000 non-null   int64
#  3   Department            5000 non-null   object
#  4   Attendance_%          5000 non-null   float64
#  5   Study_Hours_per_Week  5000 non-null   int64
#  6   Midterm_Score         5000 non-null   float64
#  7   Final_Score           5000 non-null   float64
#  8   Assignments_Avg       5000 non-null   float64
#  9   Quizzes_Avg           5000 non-null   float64
#  10  Participation_Score   5000 non-null   float64
#  11  Projects_Score        5000 non-null   float64
#  12  Total_Score           5000 non-null   float64
#  13  Grade                 5000 non-null   object
#  14  Backlogs              5000 non-null   int64
#  15  Internship            5000 non-null   object
#  16  Scholarship           5000 non-null   object
#  17  Sports_Activity       5000 non-null   object
#  18  Extra_Curricular      5000 non-null   object
#  19  Placement_Status      5000 non-null   object
# dtypes: float64(8), int64(4), object(8)
# memory usage: 781.4+ KB
