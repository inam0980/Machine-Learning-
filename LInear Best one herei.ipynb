# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, r2_score, precision_score 
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression


df=pd.read_csv("/Users/inamkhan/Desktop/MAIN/Machine Learning/Machine Learning FUll/student1.csv")

df.head()
# print(df.info())
print(df["Grade"].value_counts())
# Out:
# Grade
# D    1066
# A    1026
# B    1001
# F     958
# C     949
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Student_ID  Gender  Age   Department  Attendance_%  Study_Hours_per_Week  \
# 0           1    Male   20           CS         59.91                    30
# 1           2  Female   24  Mathematics         50.46                    31
# 2           3    Male   24     Business         81.36                    44
# 3           4    Male   24  Mathematics         65.82                    28
# 4           5    Male   21  Engineering         98.66                    12
#
#    Midterm_Score  Final_Score  Assignments_Avg  Quizzes_Avg  \
# 0          80.01        50.94            91.05        90.12
# 1          80.22        75.83            69.48        74.07
# 2          94.07        81.59            59.90        91.05
# 3          40.96        68.11            79.38        91.23
# 4          91.18        45.86            91.32        65.86
#
#    Participation_Score  Projects_Score  Total_Score Grade  Backlogs  \
# 0                53.15           71.24        49.68     C         0
# ...

# %%
X=df[["Grade","Study_Hours_per_Week"]]
y=df["Final_Score"]


# Step1 1:- train_test 

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
# Step2:- encode krna 

df=pd.get_dummies(df, columns=['Grade'])
le=LabelEncoder()
df.head()
# Out:
#    Student_ID  Gender  Age   Department  Attendance_%  Study_Hours_per_Week  \
# 0           1    Male   20           CS         59.91                    30
# 1           2  Female   24  Mathematics         50.46                    31
# 2           3    Male   24     Business         81.36                    44
# 3           4    Male   24  Mathematics         65.82                    28
# 4           5    Male   21  Engineering         98.66                    12
#
#    Midterm_Score  Final_Score  Assignments_Avg  Quizzes_Avg  ...  Internship  \
# 0          80.01        50.94            91.05        90.12  ...         Yes
# 1          80.22        75.83            69.48        74.07  ...          No
# 2          94.07        81.59            59.90        91.05  ...         Yes
# 3          40.96        68.11            79.38        91.23  ...         Yes
# 4          91.18        45.86            91.32        65.86  ...         Yes
#
# ...

# %%
#Step3 :- here i am doing scaling on one column of trained data

sc=StandardScaler()
X_train["Study_Hours_per_Week"]=sc.fit_transform(X_train[["Study_Hours_per_Week"]])

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rh/5xfb27r55ql68l4zwc899mw80000gn/T/ipykernel_71698/1265010233.py in ?()
#       1 model=LogisticRegression()
# ----> 2 model.fit(X_train,y_train)
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py in ?(self, X, y, sample_weight)
#    1243             _dtype = np.float64
#    1244         else:
#    1245             _dtype = [np.float64, np.float32]
#    1246
# ...
