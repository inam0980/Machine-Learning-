# %%
import pandas as pd
import numpy as np

data={
    'Hours':[1,2,3,4,5,6,7],
    "Score":[35,56,78,80,83,89,95]
    
}
df=pd.DataFrame(data)


df.head()
# Out:
#    Hours  Score
# 0      1     35
# 1      2     56
# 2      3     78
# 3      4     80
# 4      5     83

# %%
X=df[["Hours"]]

y=df["Score"]

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error, mean_squared_error

import numpy as np

model=LinearRegression()

model.fit(X,y)

predict= model.predict(X)

mae=mean_absolute_error(y,predict)

mse=mean_squared_error(y,predict)

rmse=np.sqrt(mse)


print("Mean Absolute Error:- ",mae)
print("Mean Squared Error:-  ",mse)
print("rms:-                 ",rmse)


new_hour=float(input("Enter study hours here:- "))

new_hour=np.array([[new_hour]])

print("YOur Score:- ",model.predict(new_hour))
# Out:
# Mean Absolute Error:-  5.734693877551022
# Mean Squared Error:-   56.19897959183671
# rms:-                  7.496597867822223
# YOur Score:-  [118.53571429]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
