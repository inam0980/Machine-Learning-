# %%
import pandas as pd

from sklearn.linear_model import LinearRegression 

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score, recall_score , r2_score ,precision_score

df=pd.read_csv("student1.csv")
df.head()
X=df[["Attendance_%","Study_Hours_per_Week"]]
y=df["Final_Score"]


model=LinearRegression()

X_train, X_test, y_train, y_test= train_test_split(X,y ,test_size=0.3, random_state=42)



sc=StandardScaler()

X_train_scale=sc.fit_transform(X_train)
X_test_scale=sc.fit_transform(X_test)

model.fit(X_train_scale,y_train)

y_pred=model.predict(X_test_scale)

print("MOdel Prediction:- ",y_pred)

print("r2 score :- ",r2_score(y_test,y_pred))
# Out:
# MOdel Prediction:-  [70.31874433 69.91316691 69.9529119  ... 70.06348035 70.5055268
#  70.30781806]
# r2 score :-  -0.0015678395261500278
